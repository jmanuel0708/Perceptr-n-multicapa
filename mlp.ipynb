# %% [markdown]
# # Práctica 1: Perceptrón multicapa.
#
# Tu jefe pidió a RH que recolectara datos de desempeño de tus compañeros, los resultados se almacenaron en un csv. El punto critico de estos datos es la satisfacción del empleado, entonces ¿Podremos estimar la satisfacción de los empleados con los datos recabados?.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from tensorflow.keras import layers, models


df = pd.read_csv('Extended_Employee_Performance_and_Productivity_Data.csv')
df.info()
# Out:
# /Users/josefo/Documents/Hybridge/6to Cuatrimestre/Sistemas de Aprendizaje Profundo/Perceptron/Perceptr-n-multicapa/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Employee_ID                  100000 non-null  int64
#  1   Department                   100000 non-null  object
#  2   Gender                       100000 non-null  object
#  3   Age                          100000 non-null  int64
#  4   Job_Title                    100000 non-null  object
#  5   Hire_Date                    100000 non-null  object
#  6   Years_At_Company             100000 non-null  int64
#  7   Education_Level              100000 non-null  object
#  8   Performance_Score            100000 non-null  int64
#  9   Monthly_Salary               100000 non-null  float64
#  10  Work_Hours_Per_Week          100000 non-null  int64
#  11  Projects_Handled             100000 non-null  int64
#  12  Overtime_Hours               100000 non-null  int64
#  13  Sick_Days                    100000 non-null  int64
#  14  Remote_Work_Frequency        100000 non-null  int64
#  15  Team_Size                    100000 non-null  int64
#  16  Training_Hours               100000 non-null  int64
#  17  Promotions                   100000 non-null  int64
#  18  Employee_Satisfaction_Score  100000 non-null  float64
#  19  Resigned                     100000 non-null  bool
# dtypes: bool(1), float64(2), int64(12), object(5)
# memory usage: 14.6+ MB

# %%
# Filtrar las columnas numéricas
numeric_columns = df.select_dtypes(include=['number']).drop('Employee_ID',axis=1)


# Si numeric_columns es un Index, conviértelo a lista
cols = list(numeric_columns)

fig, axes = plt.subplots(1, len(cols), figsize=(5 * len(cols), 4))

for i, col in enumerate(cols):
    axes[i].hist(df[col], bins=20, color='skyblue', edgecolor='black')
    axes[i].set_title(col)
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Problemas**, tenemos distribuciones con picos, esos nos indica categorías. Por otro lado, tenemos variables con "valles" en su distribución (distribuciones multimodales) por lo que resultaría óptimo aplicar técnicas de feature engeneering. Por último tenemos distribuciones uniformes, por lo que cada una requeriría un procesamiento indivudual, hagamos la vista gorda e intentemos ajustar un MLP con estos datos, solo estandaricemos nuestros datos.

# %% [markdown]
# ---
#
# ## Implementación de Red:
#
# To**memos los datos numéricos como nuestra variable X, y la variable objetivo como ***'Employee_Satisfaction_Score'***.
# - **Actividad 1**: Para todos los strings ``'@modif@'`` que aparescan en el siguiente bloque de código cámbialos para que el código funcione.

# %%
X = numeric_columns.drop('Employee_Satisfaction_Score', axis=1)
y = numeric_columns['Employee_Satisfaction_Score']
y = y.apply(lambda x: round(x) - 1) #Cambiamos la variable objetivo a 5 categorías numéricas

scaler = StandardScaler()
X_standar = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_standar, y, test_size=0.33, random_state=42)

y_onehot_train = tf.keras.utils.to_categorical(y_train, 5)
y_onehot_test = tf.keras.utils.to_categorical(y_test, 5)

# %% [markdown]
# - **Actividad 2:** Implementa 3 arquitecturas de MLP, cada una con su propio nombre, cambiando la estructura de dichas arquitecturas (capas, neuronas por capa, función de activación, etc).

# %%
# Modelo 1: arquitectura base
modelo_mlp_1 = models.Sequential([
    layers.Input(shape=(X_train.shape[1],)),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(5, activation='softmax')
])

# Modelo 2: arquitectura más profunda
modelo_mlp_2 = models.Sequential([
    layers.Input(shape=(X_train.shape[1],)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(5, activation='softmax')
])

# Modelo 3: arquitectura alternativa con activaciones distintas
modelo_mlp_3 = models.Sequential([
    layers.Input(shape=(X_train.shape[1],)),
    layers.Dense(128, activation='tanh'),
    layers.Dense(64, activation='relu'),
    layers.Dense(5, activation='softmax')
])

modelo_mlp_1.summary()
modelo_mlp_2.summary()
modelo_mlp_3.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │           165 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,077 (12.02 KB)
#  Trainable params: 3,077 (12.02 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 128)            │         1,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 5)              │           165 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,165 (47.52 KB)
#  Trainable params: 12,165 (47.52 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (None, 128)            │         1,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,245 (40.02 KB)
#  Trainable params: 10,245 (40.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# - **Actividad 3:** Compila y ajusta tus tres modelos con sus respectivos hiperparámetros.

# %%
# Compilación de los tres modelos con hiperparámetros diferentes
modelo_mlp_1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
modelo_mlp_2.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
modelo_mlp_3.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# Entrenamiento
historia_mlp_1 = modelo_mlp_1.fit(
    X_train, y_onehot_train,
    validation_data=(X_test, y_onehot_test),
    epochs=20,
    batch_size=32,
    verbose=1
)

historia_mlp_2 = modelo_mlp_2.fit(
    X_train, y_onehot_train,
    validation_data=(X_test, y_onehot_test),
    epochs=20,
    batch_size=16,
    verbose=1
)

historia_mlp_3 = modelo_mlp_3.fit(
    X_train, y_onehot_train,
    validation_data=(X_test, y_onehot_test),
    epochs=20,
    batch_size=64,
    verbose=1
)
# Out:
# Epoch 1/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 671us/step - accuracy: 0.2513 - loss: 1.5701 - val_accuracy: 0.2544 - val_loss: 1.5597
# Epoch 2/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 1s 640us/step - accuracy: 0.2637 - loss: 1.5562 - val_accuracy: 0.2534 - val_loss: 1.5588
# Epoch 3/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 1s 650us/step - accuracy: 0.2658 - loss: 1.5545 - val_accuracy: 0.2530 - val_loss: 1.5590
# Epoch 4/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 1s 617us/step - accuracy: 0.2730 - loss: 1.5531 - val_accuracy: 0.2539 - val_loss: 1.5587
# Epoch 5/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 1s 622us/step - accuracy: 0.2731 - loss: 1.5510 - val_accuracy: 0.2515 - val_loss: 1.5599
# Epoch 6/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 1s 672us/step - accuracy: 0.2755 - loss: 1.5528 - val_accuracy: 0.2538 - val_loss: 1.5602
# Epoch 7/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 1s 619us/step - accuracy: 0.2717 - loss: 1.5529 - val_accuracy: 0.2536 - val_loss: 1.5609
# Epoch 8/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 1s 621us/step - accuracy: 0.2752 - loss: 1.5508 - val_accuracy: 0.2543 - val_loss: 1.5608
# Epoch 9/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 871us/step - accuracy: 0.2844 - loss: 1.5484 - val_accuracy: 0.2546 - val_loss: 1.5632
# Epoch 10/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 813us/step - accuracy: 0.2832 - loss: 1.5470 - val_accuracy: 0.2544 - val_loss: 1.5629
# Epoch 11/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 793us/step - accuracy: 0.2850 - loss: 1.5464 - val_accuracy: 0.2540 - val_loss: 1.5651
# Epoch 12/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 1s 705us/step - accuracy: 0.2836 - loss: 1.5448 - val_accuracy: 0.2537 - val_loss: 1.5655
# Epoch 13/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 775us/step - accuracy: 0.2857 - loss: 1.5442 - val_accuracy: 0.2538 - val_loss: 1.5663
# Epoch 14/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 804us/step - accuracy: 0.2898 - loss: 1.5426 - val_accuracy: 0.2513 - val_loss: 1.5667
# Epoch 15/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 1s 636us/step - accuracy: 0.2908 - loss: 1.5435 - val_accuracy: 0.2511 - val_loss: 1.5671
# Epoch 16/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 753us/step - accuracy: 0.2904 - loss: 1.5389 - val_accuracy: 0.2541 - val_loss: 1.5661
# Epoch 17/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 724us/step - accuracy: 0.2957 - loss: 1.5388 - val_accuracy: 0.2529 - val_loss: 1.5689
# Epoch 18/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 1s 694us/step - accuracy: 0.2979 - loss: 1.5364 - val_accuracy: 0.2515 - val_loss: 1.5682
# Epoch 19/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 1s 675us/step - accuracy: 0.2979 - loss: 1.5366 - val_accuracy: 0.2545 - val_loss: 1.5721
# Epoch 20/20
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 1s 692us/step - accuracy: 0.2918 - loss: 1.5395 - val_accuracy: 0.2549 - val_loss: 1.5698
# Epoch 1/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 4s 795us/step - accuracy: 0.2538 - loss: 1.5626 - val_accuracy: 0.2527 - val_loss: 1.5588
# Epoch 2/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 679us/step - accuracy: 0.2521 - loss: 1.5585 - val_accuracy: 0.2544 - val_loss: 1.5600
# Epoch 3/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 4s 842us/step - accuracy: 0.2553 - loss: 1.5598 - val_accuracy: 0.2521 - val_loss: 1.5594
# Epoch 4/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 671us/step - accuracy: 0.2586 - loss: 1.5563 - val_accuracy: 0.2532 - val_loss: 1.5629
# Epoch 5/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 663us/step - accuracy: 0.2586 - loss: 1.5567 - val_accuracy: 0.2501 - val_loss: 1.5594
# Epoch 6/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 681us/step - accuracy: 0.2639 - loss: 1.5558 - val_accuracy: 0.2509 - val_loss: 1.5591
# Epoch 7/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 671us/step - accuracy: 0.2559 - loss: 1.5572 - val_accuracy: 0.2517 - val_loss: 1.5587
# Epoch 8/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 658us/step - accuracy: 0.2628 - loss: 1.5545 - val_accuracy: 0.2499 - val_loss: 1.5627
# Epoch 9/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 774us/step - accuracy: 0.2584 - loss: 1.5563 - val_accuracy: 0.2518 - val_loss: 1.5583
# Epoch 10/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 669us/step - accuracy: 0.2622 - loss: 1.5537 - val_accuracy: 0.2509 - val_loss: 1.5592
# Epoch 11/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 665us/step - accuracy: 0.2555 - loss: 1.5575 - val_accuracy: 0.2515 - val_loss: 1.5587
# Epoch 12/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 659us/step - accuracy: 0.2540 - loss: 1.5565 - val_accuracy: 0.2516 - val_loss: 1.5593
# Epoch 13/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 4s 968us/step - accuracy: 0.2557 - loss: 1.5557 - val_accuracy: 0.2511 - val_loss: 1.5607
# Epoch 14/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 716us/step - accuracy: 0.2553 - loss: 1.5551 - val_accuracy: 0.2511 - val_loss: 1.5603
# Epoch 15/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 745us/step - accuracy: 0.2532 - loss: 1.5562 - val_accuracy: 0.2511 - val_loss: 1.5571
# Epoch 16/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 654us/step - accuracy: 0.2559 - loss: 1.5559 - val_accuracy: 0.2518 - val_loss: 1.5581
# Epoch 17/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 667us/step - accuracy: 0.2507 - loss: 1.5547 - val_accuracy: 0.2511 - val_loss: 1.5575
# Epoch 18/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 765us/step - accuracy: 0.2535 - loss: 1.5573 - val_accuracy: 0.2516 - val_loss: 1.5603
# Epoch 19/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 668us/step - accuracy: 0.2503 - loss: 1.5559 - val_accuracy: 0.2514 - val_loss: 1.5603
# Epoch 20/20
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 734us/step - accuracy: 0.2577 - loss: 1.5557 - val_accuracy: 0.2530 - val_loss: 1.5571
# Epoch 1/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 788us/step - accuracy: 0.2410 - loss: 1.5880 - val_accuracy: 0.2543 - val_loss: 1.5635
# Epoch 2/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 696us/step - accuracy: 0.2562 - loss: 1.5610 - val_accuracy: 0.2538 - val_loss: 1.5615
# Epoch 3/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 690us/step - accuracy: 0.2555 - loss: 1.5577 - val_accuracy: 0.2522 - val_loss: 1.5603
# Epoch 4/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 701us/step - accuracy: 0.2628 - loss: 1.5553 - val_accuracy: 0.2501 - val_loss: 1.5603
# Epoch 5/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 691us/step - accuracy: 0.2660 - loss: 1.5555 - val_accuracy: 0.2527 - val_loss: 1.5602
# Epoch 6/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 739us/step - accuracy: 0.2652 - loss: 1.5552 - val_accuracy: 0.2531 - val_loss: 1.5599
# Epoch 7/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 693us/step - accuracy: 0.2686 - loss: 1.5492 - val_accuracy: 0.2531 - val_loss: 1.5598
# Epoch 8/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 697us/step - accuracy: 0.2685 - loss: 1.5533 - val_accuracy: 0.2526 - val_loss: 1.5599
# Epoch 9/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 694us/step - accuracy: 0.2670 - loss: 1.5531 - val_accuracy: 0.2513 - val_loss: 1.5600
# Epoch 10/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 700us/step - accuracy: 0.2694 - loss: 1.5535 - val_accuracy: 0.2524 - val_loss: 1.5594
# Epoch 11/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 729us/step - accuracy: 0.2704 - loss: 1.5534 - val_accuracy: 0.2526 - val_loss: 1.5594
# Epoch 12/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 700us/step - accuracy: 0.2699 - loss: 1.5521 - val_accuracy: 0.2518 - val_loss: 1.5595
# Epoch 13/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 688us/step - accuracy: 0.2694 - loss: 1.5528 - val_accuracy: 0.2523 - val_loss: 1.5595
# Epoch 14/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 700us/step - accuracy: 0.2728 - loss: 1.5528 - val_accuracy: 0.2504 - val_loss: 1.5595
# Epoch 15/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 751us/step - accuracy: 0.2730 - loss: 1.5485 - val_accuracy: 0.2545 - val_loss: 1.5594
# Epoch 16/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 790us/step - accuracy: 0.2738 - loss: 1.5521 - val_accuracy: 0.2525 - val_loss: 1.5594
# Epoch 17/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 744us/step - accuracy: 0.2720 - loss: 1.5514 - val_accuracy: 0.2530 - val_loss: 1.5594
# Epoch 18/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 831us/step - accuracy: 0.2701 - loss: 1.5547 - val_accuracy: 0.2521 - val_loss: 1.5596
# Epoch 19/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 731us/step - accuracy: 0.2720 - loss: 1.5518 - val_accuracy: 0.2513 - val_loss: 1.5594
# Epoch 20/20
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - accuracy: 0.2717 - loss: 1.5525 - val_accuracy: 0.2525 - val_loss: 1.5594
